# %%
import pandas as pd

# Charger le fichier CSV dans un DataFrame
file_path = "Relever-Nautilus-Position_UTF8.csv"  # Mets le bon chemin si nécessaire
df = pd.read_csv(file_path, delimiter=";", encoding="utf-8")

# Afficher les premières lignes pour vérifier l'importation
df.head()
# Out:
#                Escales du Nautilus               Date  Latitude_Décimal  \
# 0                    île de Crespo  1er Décembre 1866           -8.9500
# 1             Archipel des Pomotou   11 Décembre 1866          -13.5000
# 2  Archipel des nouvelles Hébrides   25 Décembre 1866          -16.0667
# 3                       La Pouasie   30 Décembre 1866           -0.3167
# 4                       Cap Wessel     2 janvier 1866          -10.7000
#
#    Longitude_Décimal            Océan/Mer
# 0          -139.5333  Océan Pacifique Sud
# 1          -151.5000  Océan Pacifique Sud
# 2           164.5333  Océan Pacifique Sud
# 3           128.3833  Océan Pacifique Sud
# 4           136.7667  Océan Pacifique Sud

# %%
import folium
print("✅ Folium est bien installé et prêt à l'emploi ! 🚀")
# Out:
# ✅ Folium est bien installé et prêt à l'emploi ! 🚀

# %%
import folium
import pandas as pd

# Charger le fichier CSV avec les escales
file_path = "Relever-Nautilus-Position_UTF81.csv"  # Assure-toi que le fichier est bien à cet emplacement
df = pd.read_csv(file_path, delimiter=";", encoding="utf-8")

# Créer une carte centrée sur un point moyen des données
m = folium.Map(location=[0, 0], zoom_start=2)

# Ajouter les escales du Nautilus sur la carte
for index, row in df.iterrows():
    folium.Marker(
        location=[row["Latitude_Décimal"], row["Longitude_Décimal"]],
        popup=f"{row['Escales du Nautilus']} ({row['Date']})",
        tooltip=row["Escales du Nautilus"]
    ).add_to(m)

# Tracer le trajet avec une ligne reliant les points
coordinates = list(zip(df["Latitude_Décimal"], df["Longitude_Décimal"]))
folium.PolyLine(locations=coordinates, color="blue", weight=2.5, opacity=1).add_to(m)

# Afficher la carte interactive
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89d7c3f4682385c03139baebc21c2282 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89d7c3f4682385c03139baebc21c2282&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89d7c3f4682385c03139baebc21c2282 = L.map(
#                 &quot;map_89d7c3f4682385c03139baebc21c2282&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_108455e99db63641b50adc5db7aa9b72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_108455e99db63641b50adc5db7aa9b72.addTo(map_89d7c3f4682385c03139baebc21c2282);
#
#
#             var marker_8572c8194d6051fdcb4e75ce0ea2e926 = L.marker(
#                 [-8.95, -139.5333],
#                 {
# }
#             ).addTo(map_89d7c3f4682385c03139baebc21c2282);
#
#
#         var popup_ed6d8d89968f9e0043aeca018fc86180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78215a11efc0735982b042416517b42e = $(`&lt;div id=&quot;html_78215a11efc0735982b042416517b42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;île de Crespo (1er Décembre 1866)&lt;/div&gt;`)[0];
#                 popup_ed6d8d89968f9e0043aeca018fc86180.setContent(html_78215a11efc0735982b042416517b42e);
#
#
#
#         marker_8572c8194d6051fdcb4e75ce0ea2e926.bindPopup(popup_ed6d8d89968f9e0043aeca018fc86180)
#         ;
#
#
#
#
#             marker_8572c8194d6051fdcb4e75ce0ea2e926.bindTooltip(
#                 `&lt;div&gt;
#                      île de Crespo
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7a7ecc0072e746a50b465bacb9f5fca1 = L.marker(
#                 [-13.5, -151.5],
#                 {
# }
#             ).addTo(map_89d7c3f4682385c03139baebc21c2282);
#
#
#         var popup_4a94c27ffb906e8e59f35c8dcb8afea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1af076ecb7ebf1e65ffcff9cdac296d2 = $(`&lt;div id=&quot;html_1af076ecb7ebf1e65ffcff9cdac296d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archipel des Pomotou (11 Décembre 1866)&lt;/div&gt;`)[0];
#                 popup_4a94c27ffb906e8e59f35c8dcb8afea3.setContent(html_1af076ecb7ebf1e65ffcff9cdac296d2);
#
#
#
#         marker_7a7ecc0072e746a50b465bacb9f5fca1.bindPopup(popup_4a94c27ffb906e8e59f35c8dcb8afea3)
#         ;
#
#
#
#
#             marker_7a7ecc0072e746a50b465bacb9f5fca1.bindTooltip(
#                 `&lt;div&gt;
#                      Archipel des Pomotou
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1c1881090440f2540c9356fa40794e5c = L.marker(
#                 [-16.0667, 164.5333],
#                 {
# }
#             ).addTo(map_89d7c3f4682385c03139baebc21c2282);
#
#
#         var popup_ee1b593a7191b6af62b1c5288f2f6042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f89ab7babfea33a83ebf6579e67c81 = $(`&lt;div id=&quot;html_85f89ab7babfea33a83ebf6579e67c81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archipel des nouvelles Hébrides (25 Décembre 1866)&lt;/div&gt;`)[0];
#                 popup_ee1b593a7191b6af62b1c5288f2f6042.setContent(html_85f89ab7babfea33a83ebf6579e67c81);
#
#
#
#         marker_1c1881090440f2540c9356fa40794e5c.bindPopup(popup_ee1b593a7191b6af62b1c5288f2f6042)
#         ;
#
#
#
#
#             marker_1c1881090440f2540c9356fa40794e5c.bindTooltip(
#                 `&lt;div&gt;
#                      Archipel des nouvelles Hébrides
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_cc7a1df2efb07fe53418eb519920620f = L.marker(
#                 [-0.3167, 128.3833],
#                 {
# }
#             ).addTo(map_89d7c3f4682385c03139baebc21c2282);
#
#
#         var popup_55cc1ecdc73c5f65f8cb0683f7b5986c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb99e195678736858d7f4e5192d0d143 = $(`&lt;div id=&quot;html_eb99e195678736858d7f4e5192d0d143&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Pouasie (30 Décembre 1866)&lt;/div&gt;`)[0];
#                 popup_55cc1ecdc73c5f65f8cb0683f7b5986c.setContent(html_eb99e195678736858d7f4e5192d0d143);
#
#
#
#         marker_cc7a1df2efb07fe53418eb519920620f.bindPopup(popup_55cc1ecdc73c5f65f8cb0683f7b5986c)
#         ;
#
#
#
#
#             marker_cc7a1df2efb07fe53418eb519920620f.bindTooltip(
#                 `&lt;div&gt;
